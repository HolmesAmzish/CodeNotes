# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')

classifier("I love using transformers for NLP tasks!")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Device set to use cuda:0
# [{'label': 'POSITIVE', 'score': 0.9982925057411194}]

# %%
# %reset -f

# %%
transcriber = pipeline("automatic-speech-recognition")
transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac")
# Out:
# No model was supplied, defaulted to facebook/wav2vec2-base-960h and revision 22aad52 (https://huggingface.co/facebook/wav2vec2-base-960h).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0
# {'text': 'I HAVE A DREAM BUT ONE DAY THIS NATION WILL RISE UP LIVE UP THE TRUE MEANING OF ITS TREES'}

# %%
transcriber = pipeline(model="openai/whisper-large-v2")
result = transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac")
print(result["text"])
# Out:
# /home/cacc/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 #transcriber = pipeline(model="openai/whisper-large-v2")
# ----> 2 result = transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac")
#       3 print(result["text"])
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/automatic_speech_recognition.py:283, in AutomaticSpeechRecognitionPipeline.__call__(self, inputs, **kwargs)
#     222 def __call__(
#     223     self,
#     224     inputs: Union[np.ndarray, bytes, str],
#     225     **kwargs,
#     226 ):
#     227     """
#     228     Transcribe the audio sequence(s) given as inputs to text. See the [`AutomaticSpeechRecognitionPipeline`]
#     229     documentation for more information.
#    (...)    281                 `"".join(chunk["text"] for chunk in output["chunks"])`.
#     282     """
# --> 283     return super().__call__(inputs, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/base.py:1371, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1369     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1370 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1371     return next(
#    1372         iter(
#    1373             self.get_iterator(
#    1374                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1375             )
#    1376         )
#    1377     )
#    1378 else:
#    1379     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:269, in PipelinePackIterator.__next__(self)
#     266             return accumulator
#     268 while not is_last:
# --> 269     processed = self.infer(next(self.iterator), **self.params)
#     270     if self.loader_batch_size is not None:
#     271         if isinstance(processed, torch.Tensor):
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/base.py:1286, in Pipeline.forward(self, model_inputs, **forward_params)
#    1284     with inference_context():
#    1285         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1286         model_outputs = self._forward(model_inputs, **forward_params)
#    1287         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1288 else:
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/pipelines/automatic_speech_recognition.py:521, in AutomaticSpeechRecognitionPipeline._forward(self, model_inputs, return_timestamps, **generate_kwargs)
#     518 if "generation_config" not in generate_kwargs:
#     519     generate_kwargs["generation_config"] = self.generation_config
# --> 521 tokens = self.model.generate(
#     522     inputs=inputs,
#     523     attention_mask=attention_mask,
#     524     **generate_kwargs,
#     525 )
#     526 # whisper longform generation stores timestamps in "segments"
#     527 if return_timestamps == "word" and self.type == "seq2seq_whisper":
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:619, in WhisperGenerationMixin.generate(self, input_features, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, return_timestamps, task, language, is_multilingual, prompt_ids, prompt_condition_type, condition_on_prev_tokens, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, num_segment_frames, attention_mask, time_precision, time_precision_features, return_token_timestamps, return_segments, return_dict_in_generate, force_unique_generate_call, **kwargs)
#     613 self._set_prompt_condition_type(
#     614     generation_config=generation_config,
#     615     prompt_condition_type=prompt_condition_type,
#     616 )
#     618 # pass self.config for backward compatibility
# --> 619 init_tokens = self._retrieve_init_tokens(
#     620     input_features,
#     621     batch_size=batch_size,
#     622     generation_config=generation_config,
#     623     config=self.config,
#     624     num_segment_frames=num_segment_frames,
#     625     kwargs=kwargs,
#     626 )
#     627 # passing `decoder_input_ids` is deprecated - the only exception is for assisted generation
#     628 # where the input ids are handled explicitly by the generate method
#     629 self._check_decoder_input_ids(kwargs=kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:1470, in WhisperGenerationMixin._retrieve_init_tokens(self, input_features, batch_size, generation_config, config, num_segment_frames, kwargs)
#    1467     lang_ids = [language_to_id(l) for l in languages]
#    1468 elif hasattr(generation_config, "lang_to_id") and is_lang_id_undefined:
#    1469     # language is not defined or intentially set to `None` to trigger language detection
# -> 1470     lang_ids = self.detect_language(
#    1471         input_features=input_features,
#    1472         encoder_outputs=kwargs.get("encoder_outputs", None),
#    1473         generation_config=generation_config,
#    1474         num_segment_frames=num_segment_frames,
#    1475     ).tolist()
#    1476 if lang_ids is not None:
#    1477     # append or replace lang_ids to init_tokens
#    1478     for i in range(len(init_tokens)):
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:1574, in WhisperGenerationMixin.detect_language(self, input_features, encoder_outputs, generation_config, num_segment_frames)
#    1568 decoder_input_ids = (
#    1569     torch.ones((batch_size, 1), device=self.device, dtype=torch.long)
#    1570     * generation_config.decoder_start_token_id
#    1571 )
#    1573 with torch.no_grad():
# -> 1574     logits = self(**inputs, decoder_input_ids=decoder_input_ids, use_cache=False).logits[:, -1]
#    1576 non_lang_mask = torch.ones_like(logits[0], dtype=torch.bool)
#    1577 non_lang_mask[list(generation_config.lang_to_id.values())] = False
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/modeling_whisper.py:1776, in WhisperForConditionalGeneration.forward(self, input_features, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, decoder_position_ids, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1771     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1772         decoder_input_ids = shift_tokens_right(
#    1773             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1774         )
# -> 1776 outputs = self.model(
#    1777     input_features,
#    1778     attention_mask=attention_mask,
#    1779     decoder_input_ids=decoder_input_ids,
#    1780     encoder_outputs=encoder_outputs,
#    1781     decoder_attention_mask=decoder_attention_mask,
#    1782     head_mask=head_mask,
#    1783     decoder_head_mask=decoder_head_mask,
#    1784     cross_attn_head_mask=cross_attn_head_mask,
#    1785     past_key_values=past_key_values,
#    1786     decoder_inputs_embeds=decoder_inputs_embeds,
#    1787     decoder_position_ids=decoder_position_ids,
#    1788     use_cache=use_cache,
#    1789     output_attentions=output_attentions,
#    1790     output_hidden_states=output_hidden_states,
#    1791     return_dict=return_dict,
#    1792     cache_position=cache_position,
#    1793 )
#    1794 lm_logits = self.proj_out(outputs[0])
#    1796 loss = None
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/modeling_whisper.py:1627, in WhisperModel.forward(self, input_features, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, decoder_position_ids, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1624 if encoder_outputs is None:
#    1625     input_features = self._mask_input_features(input_features, attention_mask=attention_mask)
# -> 1627     encoder_outputs = self.encoder(
#    1628         input_features,
#    1629         head_mask=head_mask,
#    1630         output_attentions=output_attentions,
#    1631         output_hidden_states=output_hidden_states,
#    1632         return_dict=return_dict,
#    1633     )
#    1634 # If the user passed a tuple for encoder_outputs, we wrap it in a BaseModelOutput when return_dict=True
#    1635 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llm/lib/python3.12/site-packages/transformers/models/whisper/modeling_whisper.py:1029, in WhisperEncoder.forward(self, input_features, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#    1025 output_hidden_states = (
#    1026     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1027 )
#    1028 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1029 inputs_embeds = nn.functional.gelu(self.conv1(input_features))
#    1030 inputs_embeds = nn.functional.gelu(self.conv2(inputs_embeds))
#    1032 inputs_embeds = inputs_embeds.permute(0, 2, 1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 16.00 MiB. GPU 0 has a total capacity of 7.75 GiB of which 9.25 MiB is free. Including non-PyTorch memory, this process has 7.68 GiB memory in use. Of the allocated memory 7.34 GiB is allocated by PyTorch, and 225.81 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
